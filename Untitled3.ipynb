# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/Delta.csv", header=None)
df
# Out:
#           0         1
# 0       0.1  0.012696
# 1       0.2  0.012717
# 2       0.3  0.012749
# 3       0.4  0.012798
# 4       0.5  0.012879
# ...     ...       ...
# 1146  114.7  4.385200
# 1147  114.8  4.391300
# 1148  114.9  4.396800
# 1149  115.0  4.402300
# 1150  115.1  4.407700
#
# [1151 rows x 2 columns]

# %%
root_y = np.sqrt(df[1])
root_y
# Out:
# 0       0.112677
# 1       0.112770
# 2       0.112911
# 3       0.113128
# 4       0.113486
#           ...
# 1146    2.094087
# 1147    2.095543
# 1148    2.096855
# 1149    2.098166
# 1150    2.099452
# Name: 1, Length: 1151, dtype: float64

# %%
root_y = a*df[0] + b

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
coeff1 = np.polyfit(df[0], root_y, 1)

# %%
coeff1
# Out:
# array([0.01721836, 0.12524783])

# %%
coeff2 = np.polyfit(df[0], df[1], 2)
coeff2
# Out:
# array([0.00028857, 0.00503948, 0.00888109])

# %%
y1 = np.polyval(coeff1, df[0])
y2 = np.polyval(coeff2, df[0])

# %%
y1
# Out:
# array([0.12696966, 0.1286915 , 0.13041334, ..., 2.10363687, 2.1053587 ,
#        2.10708054])

# %%
plt.plot(df[0], y1)
plt.plot(df[0], root_y, '--')
plt.legend(["fit", "actual"], loc ="lower right")

# %%
plt.plot(df[0], y2)
plt.plot(df[0], df[1], '--')
plt.legend(["fit", "actual"], loc ="lower right")

# %%
diff1 = np.abs(root_y - y1)
diff2 = np.abs(df[1] - y2)

# %%
plt.plot(diff1)

# %%
diff1[:200]
# Out:
# 0      0.014293
# 1      0.015922
# 2      0.017502
# 3      0.019007
# 4      0.020371
#          ...
# 195    0.007017
# 196    0.007122
# 197    0.007242
# 198    0.007386
# 199    0.007543
# Name: 1, Length: 200, dtype: float64

# %%
np.argmin(diff1[:200])
# Out:
# 121

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %%
fit1 = np.polyfit(df[0][:np.argmin(diff1[:200])], y2[:np.argmin(diff1[:200])], 4)
fit1
# Out:
# array([2.08598509e-21, 1.78299147e-19, 2.88566390e-04, 5.03948344e-03,
#        8.88108611e-03])

# %%
plt.plot(np.polyval(fit1, df[0][:np.argmin(diff1[:200])] ))
plt.plot(y2[:np.argmin(diff1[:200])])
plt.legend(["fit", "actual"], loc ="lower right")

# %%
plt.plot(diff2)

# %%
y_segment1 = np.polyval(fit1, df[0][:np.argmin(diff1[:200])])

# %%
y_segment2 = y1*y1

# %%
y_new1 = np.concatenate((y_segment1, y_segment2))

# %%
plt.plot(y_new1)
plt.plot(df[1])
plt.legend(["fit", "actual"], loc ="lower right")

# %%
y_new1
# Out:
# array([0.00938792, 0.00990053, 0.0104189 , ..., 4.42528807, 4.43253527,
#        4.4397884 ])

# %%
y_new1.shape
# Out:
# (1272,)

# %%
df[y_new1] = y_new1

# %%
df[y_new1].shape
# Out:
# (1151, 1272)
